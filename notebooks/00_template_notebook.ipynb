# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

from repo_name.paths import find_project_root

# %%
root_dir = find_project_root()
figs_dir = root_dir / "data/figs"
os.chdir(root_dir)

# %% [markdown]
# # Helper functions

# %% [markdown]
# # Analysis
